# %%
        import tensorflow as tf
        import pandas as pd
        import numpy as np
        from sklearn.preprocessing import minmax_scale
        from sklearn.svm import SVC
        from sklearn.metrics import confusion_matrix
        from sklearn.metrics import precision_score, recall_score
        from sklearn.metrics import f1_score
        from sklearn.metrics import accuracy_score


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Train.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        train_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        train_labels = HDFC_Working["Target"].copy()
        train_labels_1 = (train_labels == 1)
        train_labels_0 = (train_labels == 0)


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Valid.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        valid_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        valid_labels = HDFC_Working["Target"].copy()
        valid_labels_1 = (valid_labels == 1)
        valid_labels_0 = (valid_labels == 0)


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Test.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        test_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        test_labels = HDFC_Working["Target"].copy()
        test_labels[544] = 1
        test_labels_1 = (test_labels == 1)
        test_labels_0 = (test_labels == 0)
        
        

        cross_val_test_features = valid_features.copy()

        cross_val_test_labels = valid_labels.copy()
        
        cross_val_train_features = [train_features, valid_features]
        cross_val_train_features = pd.concat(cross_val_train_features)
        
        cross_val_train_labels = [train_labels, valid_labels]
        cross_val_train_labels = pd.concat(cross_val_train_labels)

    

      
        rbf_svm_clf_1 = SVC(kernel="rbf", C = 0.01)
        print("RBF SVM with C = 0.01 Average Performance Measures:\n ")
       
        total_prec = 0
        total_rec = 0
        total_f1 = 0
        total_neg_prec = 0
        total_spec = 0
        total_f2 = 0
        total_acc = 0
        
        total_tp = 0
        total_tn = 0
        total_fp = 0
        total_fn = 0

        for i in range (0, 5):
            
            train_features_X = cross_val_train_features[ : 1635 + (i*109)]
            train_labels_X = cross_val_train_labels[ : 1635 + (i*109)]

            cross_val_test_features_X = cross_val_test_features[i*109 : (i + 1)*109]
            cross_val_test_labels_X = cross_val_test_labels[i*109 : (i + 1)*109]

            rbf_svm_clf_1.fit(train_features_X, train_labels_X)

            train_preds = rbf_svm_clf_1.predict(cross_val_test_features_X)
            
            cm = confusion_matrix(cross_val_test_labels_X, train_preds)
            
            tp = cm[1,1]
            tn = cm[0,0]
            fp = cm[0,1]
            fn = cm[1, 0]
            
            total_tp = total_tp + cm[1, 1]
            total_tn = total_tn + cm[0, 0]
            total_fp = total_fp + cm[0, 1]
            total_fn = total_fn + cm[1, 0]
            
            total_prec = total_prec + (precision_score(cross_val_test_labels_X, train_preds)*(tp+fp))
            
            total_rec = total_rec + (recall_score(cross_val_test_labels_X, train_preds)*(tp+fn))
            
            total_f1 = total_f1 + f1_score(cross_val_test_labels_X, train_preds)
            
            total_acc = total_acc + (accuracy_score(cross_val_test_labels_X, train_preds)*(tp+tn+fp+fn))
          
            Neg_Prec = cm[0,0]/(cm[0,0] + cm[1,0])
            total_neg_prec = total_neg_prec + (Neg_Prec*(tn+fn))
         
            spec = cm[0,0]/(cm[0,0] + cm[0,1])
            total_spec = total_spec + (spec*(tn+fp))
            
            f2 = 2*(Neg_Prec*spec)/(Neg_Prec + spec)
            total_f2 = total_f2 + f2
            
        print("Precision:\n")
        print((total_prec / (total_tp + total_fp))*100)
        
        print("\nRecall:\n")
        print((total_rec/(total_tp + total_fn))*100)
        
        print("\nNegative Precision:\n")
        print((total_neg_prec/(total_tn + total_fn))*100)
        
        print("\nSpecificity:\n")
        print((total_spec/(total_tn + total_fp))*100)
        
        print("\nAccuracy:")
        print((total_acc/(total_tp + total_tn + total_fp + total_fn))*100)
        
        rbf_svm_clf_1.fit(cross_val_train_features[0 : 2180], cross_val_train_labels[0 : 2180])
# Out:
# RBF SVM with C = 0.01 Average Performance Measures:
# C:\Users\MOHIT.K\Desktop\NLP\Anaconda\lib\site-packages\ipykernel_launcher.py:207: RuntimeWarning: invalid value encountered in longlong_scalars
# C:\Users\MOHIT.K\Desktop\NLP\Anaconda\lib\site-packages\ipykernel_launcher.py:207: RuntimeWarning: invalid value encountered in longlong_scalars
# C:\Users\MOHIT.K\Desktop\NLP\Anaconda\lib\site-packages\ipykernel_launcher.py:207: RuntimeWarning: invalid value encountered in longlong_scalars
# C:\Users\MOHIT.K\Desktop\NLP\Anaconda\lib\site-packages\ipykernel_launcher.py:207: RuntimeWarning: invalid value encountered in longlong_scalars
# C:\Users\MOHIT.K\Desktop\NLP\Anaconda\lib\site-packages\ipykernel_launcher.py:207: RuntimeWarning: invalid value encountered in longlong_scalars
# Precision:
#
# 53.94495412844037
#
# Recall:
#
# 100.0
#
# Negative Precision:
#
# nan
#
# Specificity:
#
# 0.0
#
# Accuracy:
# 53.94495412844037
# SVC(C=0.01)

# %%
        import tensorflow as tf
        import pandas as pd
        import numpy as np
        from sklearn.preprocessing import minmax_scale
        from sklearn.svm import SVC
        from sklearn.metrics import confusion_matrix
        from sklearn.metrics import precision_score, recall_score
        from sklearn.metrics import f1_score
        from sklearn.metrics import accuracy_score


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Train.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        train_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        train_labels = HDFC_Working["Target"].copy()
        train_labels_1 = (train_labels == 1)
        train_labels_0 = (train_labels == 0)


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Valid.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        valid_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        valid_labels = HDFC_Working["Target"].copy()
        valid_labels_1 = (valid_labels == 1)
        valid_labels_0 = (valid_labels == 0)


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Test.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        test_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        test_labels = HDFC_Working["Target"].copy()
        test_labels[544] = 1
        test_labels_1 = (test_labels == 1)
        test_labels_0 = (test_labels == 0)

        cross_val_test_features = valid_features.copy()

        cross_val_test_labels = valid_labels.copy()

        cross_val_train_features = [train_features, valid_features]
        cross_val_train_features = pd.concat(cross_val_train_features)
        
        cross_val_train_labels = [train_labels, valid_labels]
        cross_val_train_labels = pd.concat(cross_val_train_labels)

     
        rbf_svm_clf_2 = SVC(kernel="rbf", C = 0.1)
        print("\nRBF SVM with C = 0.1 Average Performance Measures:\n ")
    
        total_prec = 0
        total_rec = 0
        total_f1 = 0
        total_neg_prec = 0
        total_spec = 0
        total_f2 = 0
        total_acc = 0
        
        total_tp = 0
        total_tn = 0
        total_fp = 0
        total_fn = 0

        for i in range (0, 5):
            
            train_features_X = cross_val_train_features[ : 1635 + (i*109)]
            train_labels_X = cross_val_train_labels[ : 1635 + (i*109)]

            cross_val_test_features_X = cross_val_test_features[i*109 : (i + 1)*109]
            cross_val_test_labels_X = cross_val_test_labels[i*109 : (i + 1)*109]

            rbf_svm_clf_2.fit(train_features_X, train_labels_X)

            train_preds = rbf_svm_clf_2.predict(cross_val_test_features_X)
            
            cm = confusion_matrix(cross_val_test_labels_X, train_preds)
            
            tp = cm[1,1]
            tn = cm[0,0]
            fp = cm[0,1]
            fn = cm[1, 0]
            
            total_tp = total_tp + cm[1, 1]
            total_tn = total_tn + cm[0, 0]
            total_fp = total_fp + cm[0, 1]
            total_fn = total_fn + cm[1, 0]
            
            total_prec = total_prec + (precision_score(cross_val_test_labels_X, train_preds)*(tp+fp))
            
            total_rec = total_rec + (recall_score(cross_val_test_labels_X, train_preds)*(tp+fn))
            
            total_f1 = total_f1 + f1_score(cross_val_test_labels_X, train_preds)
            
            total_acc = total_acc + (accuracy_score(cross_val_test_labels_X, train_preds)*(tp+tn+fp+fn))
          
            Neg_Prec = cm[0,0]/(cm[0,0] + cm[1,0])
            total_neg_prec = total_neg_prec + (Neg_Prec*(tn+fn))
         
            spec = cm[0,0]/(cm[0,0] + cm[0,1])
            total_spec = total_spec + (spec*(tn+fp))
            
            f2 = 2*(Neg_Prec*spec)/(Neg_Prec + spec)
            total_f2 = total_f2 + f2
            
        print("Precision:\n")
        print((total_prec / (total_tp + total_fp))*100)
        
        print("\nRecall:\n")
        print((total_rec/(total_tp + total_fn))*100)
        
        print("\nNegative Precision:\n")
        print((total_neg_prec/(total_tn + total_fn))*100)
        
        print("\nSpecificity:\n")
        print((total_spec/(total_tn + total_fp))*100)
        
        print("\nAccuracy:")
        print((total_acc/(total_tp + total_tn + total_fp + total_fn))*100)
        
        rbf_svm_clf_2.fit(cross_val_train_features[0 : 2180], cross_val_train_labels[0 : 2180])
# Out:
# RBF SVM with C = 0.1 Average Performance Measures:
# C:\Users\MOHIT.K\Desktop\NLP\Anaconda\lib\site-packages\ipykernel_launcher.py:203: RuntimeWarning: invalid value encountered in longlong_scalars
# Precision:
#
# 53.941908713692946
#
# Recall:
#
# 88.43537414965986
#
# Negative Precision:
#
# nan
#
# Specificity:
#
# 11.553784860557768
#
# Accuracy:
# 53.027522935779814
# SVC(C=0.1)

# %%
        import tensorflow as tf
        import pandas as pd
        import numpy as np
        from sklearn.preprocessing import minmax_scale
        from sklearn.svm import SVC
        from sklearn.metrics import confusion_matrix
        from sklearn.metrics import precision_score, recall_score
        from sklearn.metrics import f1_score
        from sklearn.metrics import accuracy_score


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Train.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        train_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        train_labels = HDFC_Working["Target"].copy()
        train_labels_1 = (train_labels == 1)
        train_labels_0 = (train_labels == 0)


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Valid.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        valid_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        valid_labels = HDFC_Working["Target"].copy()
        valid_labels_1 = (valid_labels == 1)
        valid_labels_0 = (valid_labels == 0)


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Test.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        test_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        test_labels = HDFC_Working["Target"].copy()
        test_labels[544] = 1
        test_labels_1 = (test_labels == 1)
        test_labels_0 = (test_labels == 0)

        cross_val_test_features = valid_features.copy()

        cross_val_test_labels = valid_labels.copy()

    
        cross_val_train_features = [train_features, valid_features]
        cross_val_train_features = pd.concat(cross_val_train_features)
        
        cross_val_train_labels = [train_labels, valid_labels]
        cross_val_train_labels = pd.concat(cross_val_train_labels)

        rbf_svm_clf_3 = SVC(kernel="rbf", C = 1)
        print("\n\nRBF SVM with C = 1 Average Performance Measures:\n ")
      
            
        total_prec = 0
        total_rec = 0
        total_f1 = 0
        total_neg_prec = 0
        total_spec = 0
        total_f2 = 0
        total_acc = 0
        
        total_tp = 0
        total_tn = 0
        total_fp = 0
        total_fn = 0

        for i in range (0, 5):
            
            train_features_X = cross_val_train_features[ : 1635 + (i*109)]
            train_labels_X = cross_val_train_labels[ : 1635 + (i*109)]

            cross_val_test_features_X = cross_val_test_features[i*109 : (i + 1)*109]
            cross_val_test_labels_X = cross_val_test_labels[i*109 : (i + 1)*109]

            rbf_svm_clf_3.fit(train_features_X, train_labels_X)

            train_preds = rbf_svm_clf_3.predict(cross_val_test_features_X)
            
            cm = confusion_matrix(cross_val_test_labels_X, train_preds)
            
            tp = cm[1,1]
            tn = cm[0,0]
            fp = cm[0,1]
            fn = cm[1, 0]
            
            total_tp = total_tp + cm[1, 1]
            total_tn = total_tn + cm[0, 0]
            total_fp = total_fp + cm[0, 1]
            total_fn = total_fn + cm[1, 0]
            
            total_prec = total_prec + (precision_score(cross_val_test_labels_X, train_preds)*(tp+fp))
            
            total_rec = total_rec + (recall_score(cross_val_test_labels_X, train_preds)*(tp+fn))
            
            total_f1 = total_f1 + f1_score(cross_val_test_labels_X, train_preds)
            
            total_acc = total_acc + (accuracy_score(cross_val_test_labels_X, train_preds)*(tp+tn+fp+fn))
          
            Neg_Prec = cm[0,0]/(cm[0,0] + cm[1,0])
            total_neg_prec = total_neg_prec + (Neg_Prec*(tn+fn))
         
            spec = cm[0,0]/(cm[0,0] + cm[0,1])
            total_spec = total_spec + (spec*(tn+fp))
            
            f2 = 2*(Neg_Prec*spec)/(Neg_Prec + spec)
            total_f2 = total_f2 + f2
            
        print("Precision:\n")
        print((total_prec / (total_tp + total_fp))*100)
        
        print("\nRecall:\n")
        print((total_rec/(total_tp + total_fn))*100)
        
        print("\nNegative Precision:\n")
        print((total_neg_prec/(total_tn + total_fn))*100)
        
        print("\nSpecificity:\n")
        print((total_spec/(total_tn + total_fp))*100)
        
        print("\nAccuracy:")
        print((total_acc/(total_tp + total_tn + total_fp + total_fn))*100)
        
        rbf_svm_clf_3.fit(cross_val_train_features[0 : 2180], cross_val_train_labels[0 : 2180])
# Out:
# RBF SVM with C = 1 Average Performance Measures:
#
# Precision:
#
# 53.48314606741573
#
# Recall:
#
# 80.95238095238095
#
# Negative Precision:
#
# 44.0
#
# Specificity:
#
# 17.52988047808765
#
# Accuracy:
# 51.74311926605505
# SVC(C=1)

# %%
        import tensorflow as tf
        import pandas as pd
        import numpy as np
        from sklearn.preprocessing import minmax_scale
        from sklearn.svm import SVC
        from sklearn.metrics import confusion_matrix
        from sklearn.metrics import precision_score, recall_score
        from sklearn.metrics import f1_score
        from sklearn.metrics import accuracy_score


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Train.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        train_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        train_labels = HDFC_Working["Target"].copy()
        train_labels_1 = (train_labels == 1)
        train_labels_0 = (train_labels == 0)


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Valid.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        valid_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        valid_labels = HDFC_Working["Target"].copy()
        valid_labels_1 = (valid_labels == 1)
        valid_labels_0 = (valid_labels == 0)


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Test.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        test_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        test_labels = HDFC_Working["Target"].copy()
        test_labels[544] = 1
        test_labels_1 = (test_labels == 1)
        test_labels_0 = (test_labels == 0)

        cross_val_test_features = valid_features.copy()

        cross_val_test_labels = valid_labels.copy()

        cross_val_train_features = [train_features, valid_features]
        cross_val_train_features = pd.concat(cross_val_train_features)
        
        cross_val_train_labels = [train_labels, valid_labels]
        cross_val_train_labels = pd.concat(cross_val_train_labels)

     
        rbf_svm_clf_4 = SVC(kernel="rbf", C = 10)
        print("\n\nRBF SVM with C = 10 Average Performance Measures:\n ")
     
            
        total_prec = 0
        total_rec = 0
        total_f1 = 0
        total_neg_prec = 0
        total_spec = 0
        total_f2 = 0
        total_acc = 0
        
        total_tp = 0
        total_tn = 0
        total_fp = 0
        total_fn = 0

        for i in range (0, 5):
            
            train_features_X = cross_val_train_features[ : 1635 + (i*109)]
            train_labels_X = cross_val_train_labels[ : 1635 + (i*109)]

            cross_val_test_features_X = cross_val_test_features[i*109 : (i + 1)*109]
            cross_val_test_labels_X = cross_val_test_labels[i*109 : (i + 1)*109]

            rbf_svm_clf_4.fit(train_features_X, train_labels_X)

            train_preds = rbf_svm_clf_4.predict(cross_val_test_features_X)
            
            cm = confusion_matrix(cross_val_test_labels_X, train_preds)
            
            tp = cm[1,1]
            tn = cm[0,0]
            fp = cm[0,1]
            fn = cm[1, 0]
            
            total_tp = total_tp + cm[1, 1]
            total_tn = total_tn + cm[0, 0]
            total_fp = total_fp + cm[0, 1]
            total_fn = total_fn + cm[1, 0]
            
            total_prec = total_prec + (precision_score(cross_val_test_labels_X, train_preds)*(tp+fp))
            
            total_rec = total_rec + (recall_score(cross_val_test_labels_X, train_preds)*(tp+fn))
            
            total_f1 = total_f1 + f1_score(cross_val_test_labels_X, train_preds)
            
            total_acc = total_acc + (accuracy_score(cross_val_test_labels_X, train_preds)*(tp+tn+fp+fn))
          
            Neg_Prec = cm[0,0]/(cm[0,0] + cm[1,0])
            total_neg_prec = total_neg_prec + (Neg_Prec*(tn+fn))
         
            spec = cm[0,0]/(cm[0,0] + cm[0,1])
            total_spec = total_spec + (spec*(tn+fp))
            
            f2 = 2*(Neg_Prec*spec)/(Neg_Prec + spec)
            total_f2 = total_f2 + f2
            
        print("Precision:\n")
        print((total_prec / (total_tp + total_fp))*100)
        
        print("\nRecall:\n")
        print((total_rec/(total_tp + total_fn))*100)
        
        print("\nNegative Precision:\n")
        print((total_neg_prec/(total_tn + total_fn))*100)
        
        print("\nSpecificity:\n")
        print((total_spec/(total_tn + total_fp))*100)
        
        print("\nAccuracy:")
        print((total_acc/(total_tp + total_tn + total_fp + total_fn))*100)
        
        rbf_svm_clf_4.fit(cross_val_train_features[0 : 2180], cross_val_train_labels[0 : 2180])
# Out:
# RBF SVM with C = 10 Average Performance Measures:
#
# Precision:
#
# 53.591160220994475
#
# Recall:
#
# 65.98639455782312
#
# Negative Precision:
#
# 45.3551912568306
#
# Specificity:
#
# 33.067729083665334
#
# Accuracy:
# 50.825688073394495
# SVC(C=10)

# %%
        import tensorflow as tf
        import pandas as pd
        import numpy as np
        from sklearn.preprocessing import minmax_scale
        from sklearn.svm import SVC
        from sklearn.metrics import confusion_matrix
        from sklearn.metrics import precision_score, recall_score
        from sklearn.metrics import f1_score
        from sklearn.metrics import accuracy_score


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Train.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        train_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        train_labels = HDFC_Working["Target"].copy()
        train_labels_1 = (train_labels == 1)
        train_labels_0 = (train_labels == 0)


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Valid.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        valid_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        valid_labels = HDFC_Working["Target"].copy()
        valid_labels_1 = (valid_labels == 1)
        valid_labels_0 = (valid_labels == 0)


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Test.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        test_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        test_labels = HDFC_Working["Target"].copy()
        test_labels[544] = 1
        test_labels_1 = (test_labels == 1)
        test_labels_0 = (test_labels == 0)

        cross_val_test_features = valid_features.copy()

        cross_val_test_labels = valid_labels.copy()
        
        cross_val_train_features = [train_features, valid_features]
        cross_val_train_features = pd.concat(cross_val_train_features)
        
        cross_val_train_labels = [train_labels, valid_labels]
        cross_val_train_labels = pd.concat(cross_val_train_labels)

    
        rbf_svm_clf_5 = SVC(kernel="rbf", C = 100)
        print("\n\nRBF SVM with C = 100 Average Performance Measures:\n ")
            
        total_prec = 0
        total_rec = 0
        total_f1 = 0
        total_neg_prec = 0
        total_spec = 0
        total_f2 = 0
        total_acc = 0
        
        total_tp = 0
        total_tn = 0
        total_fp = 0
        total_fn = 0

        for i in range (0, 5):
            
            train_features_X = cross_val_train_features[ : 1635 + (i*109)]
            train_labels_X = cross_val_train_labels[ : 1635 + (i*109)]

            cross_val_test_features_X = cross_val_test_features[i*109 : (i + 1)*109]
            cross_val_test_labels_X = cross_val_test_labels[i*109 : (i + 1)*109]

            rbf_svm_clf_5.fit(train_features_X, train_labels_X)

            train_preds = rbf_svm_clf_5.predict(cross_val_test_features_X)
            
            cm = confusion_matrix(cross_val_test_labels_X, train_preds)
            
            tp = cm[1,1]
            tn = cm[0,0]
            fp = cm[0,1]
            fn = cm[1, 0]
            
            total_tp = total_tp + cm[1, 1]
            total_tn = total_tn + cm[0, 0]
            total_fp = total_fp + cm[0, 1]
            total_fn = total_fn + cm[1, 0]
            
            total_prec = total_prec + (precision_score(cross_val_test_labels_X, train_preds)*(tp+fp))
            
            total_rec = total_rec + (recall_score(cross_val_test_labels_X, train_preds)*(tp+fn))
            
            total_f1 = total_f1 + f1_score(cross_val_test_labels_X, train_preds)
            
            total_acc = total_acc + (accuracy_score(cross_val_test_labels_X, train_preds)*(tp+tn+fp+fn))
          
            Neg_Prec = cm[0,0]/(cm[0,0] + cm[1,0])
            total_neg_prec = total_neg_prec + (Neg_Prec*(tn+fn))
         
            spec = cm[0,0]/(cm[0,0] + cm[0,1])
            total_spec = total_spec + (spec*(tn+fp))
            
            f2 = 2*(Neg_Prec*spec)/(Neg_Prec + spec)
            total_f2 = total_f2 + f2
            
        print("Precision:\n")
        print((total_prec / (total_tp + total_fp))*100)
        
        print("\nRecall:\n")
        print((total_rec/(total_tp + total_fn))*100)
        
        print("\nNegative Precision:\n")
        print((total_neg_prec/(total_tn + total_fn))*100)
        
        print("\nSpecificity:\n")
        print((total_spec/(total_tn + total_fp))*100)
        
        print("\nAccuracy:")
        print((total_acc/(total_tp + total_tn + total_fp + total_fn))*100)
        
        rbf_svm_clf_5.fit(cross_val_train_features[0 : 2180], cross_val_train_labels[0 : 2180])
# Out:
# RBF SVM with C = 100 Average Performance Measures:
#
# Precision:
#
# 53.664302600472816
#
# Recall:
#
# 77.21088435374149
#
# Negative Precision:
#
# 45.08196721311475
#
# Specificity:
#
# 21.91235059760956
#
# Accuracy:
# 51.74311926605505
# SVC(C=100)

# %%
        import tensorflow as tf
        import pandas as pd
        import numpy as np
        from sklearn.preprocessing import minmax_scale
        from sklearn.svm import SVC
        from sklearn.metrics import confusion_matrix
        from sklearn.metrics import precision_score, recall_score
        from sklearn.metrics import f1_score
        from sklearn.metrics import accuracy_score


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Train.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        train_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        train_labels = HDFC_Working["Target"].copy()
        train_labels_1 = (train_labels == 1)
        train_labels_0 = (train_labels == 0)


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Valid.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        valid_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        valid_labels = HDFC_Working["Target"].copy()
        valid_labels_1 = (valid_labels == 1)
        valid_labels_0 = (valid_labels == 0)


        HDFC_Working = pd.read_csv(r'C:\Users\MOHIT.K\Desktop\HDFC_Test.csv')

        HDFC_Working["Open"] = minmax_scale(HDFC_Working["Open"], (0,1))
        HDFC_Working["High"] = minmax_scale(HDFC_Working["High"], (0,1))
        HDFC_Working["Low"] = minmax_scale(HDFC_Working["Low"], (0,1))
        HDFC_Working["Close"] = minmax_scale(HDFC_Working["Close"], (0,1))
        HDFC_Working["Volume"] = minmax_scale(HDFC_Working["Volume"], (0,1))
        HDFC_Working["Candle Body"] = minmax_scale(HDFC_Working["Candle Body"], (0,1))
        HDFC_Working["Upper Shadow"] = minmax_scale(HDFC_Working["Upper Shadow"], (0,1))
        HDFC_Working["Lower Shadow"] = minmax_scale(HDFC_Working["Lower Shadow"], (0,1))
        HDFC_Working["Range"] = minmax_scale(HDFC_Working["Range"], (0,1))
        HDFC_Working["RSI_7"] = minmax_scale(HDFC_Working["RSI_7"], (0,1))
        HDFC_Working["RSI_14"] = minmax_scale(HDFC_Working["RSI_14"], (0,1))
        HDFC_Working["RSI_21"] = minmax_scale(HDFC_Working["RSI_21"], (0,1))
        HDFC_Working["MACD (26, 12)"] = minmax_scale(HDFC_Working["MACD (26, 12)"], (0,1))
        HDFC_Working["MACD (44, 26)"] = minmax_scale(HDFC_Working["MACD (44, 26)"], (0,1))
        HDFC_Working["OBV"] = minmax_scale(HDFC_Working["OBV"], (0,1))
        HDFC_Working["ATR_7"] = minmax_scale(HDFC_Working["ATR_7"], (0,1))
        HDFC_Working["ATR_14"] = minmax_scale(HDFC_Working["ATR_14"], (0,1))
        HDFC_Working["ATR_21"] = minmax_scale(HDFC_Working["ATR_21"], (0,1))
        HDFC_Working["AO"] = minmax_scale(HDFC_Working["AO"], (0,1))
        HDFC_Working["KAMA"] = minmax_scale(HDFC_Working["KAMA"], (0,1))
        HDFC_Working["PPO"] = minmax_scale(HDFC_Working["PPO"], (0,1))
        HDFC_Working["PPO_Signal"] = minmax_scale(HDFC_Working["PPO_Signal"], (0,1))
        HDFC_Working["PVO"] = minmax_scale(HDFC_Working["PVO"], (0,1))
        HDFC_Working["PVO_Signal"] = minmax_scale(HDFC_Working["PVO_Signal"], (0,1))
        HDFC_Working["ROC"] = minmax_scale(HDFC_Working["ROC"], (0,1))
        HDFC_Working["TSI"] = minmax_scale(HDFC_Working["TSI"], (0,1))
        HDFC_Working["WR"] = minmax_scale(HDFC_Working["WR"], (0,1))
        HDFC_Working["ADI"] = minmax_scale(HDFC_Working["ADI"], (0,1))
        HDFC_Working["CMI"] = minmax_scale(HDFC_Working["CMI"], (0,1))
        HDFC_Working["FI"] = minmax_scale(HDFC_Working["FI"], (0,1))
        HDFC_Working["MFI"] = minmax_scale(HDFC_Working["MFI"], (0,1))
        HDFC_Working["NVI"] = minmax_scale(HDFC_Working["NVI"], (0,1))
        HDFC_Working["VPT"] = minmax_scale(HDFC_Working["VPT"], (0,1))
        HDFC_Working["ADX"] = minmax_scale(HDFC_Working["ADX"], (0,1))
        HDFC_Working["MASS INDEX"] = minmax_scale(HDFC_Working["MASS INDEX"], (0,1))

        test_features =  HDFC_Working.drop(['Target', 'Candle Score'], axis = 1)
        test_labels = HDFC_Working["Target"].copy()
        test_labels[544] = 1
        test_labels_1 = (test_labels == 1)
        test_labels_0 = (test_labels == 0)

        cross_val_test_features = valid_features.copy()

        cross_val_test_labels = valid_labels.copy()
        
        cross_val_train_features = [train_features, valid_features]
        cross_val_train_features = pd.concat(cross_val_train_features)
        
        cross_val_train_labels = [train_labels, valid_labels]
        cross_val_train_labels = pd.concat(cross_val_train_labels)

    
        rbf_svm_clf_6 = SVC(kernel="rbf", C = 1.25)
        print("\n\nRBF SVM with C = 1.25 Average Performance Measures:\n ")
            
        total_prec = 0
        total_rec = 0
        total_f1 = 0
        total_neg_prec = 0
        total_spec = 0
        total_f2 = 0
        total_acc = 0
        
        total_tp = 0
        total_tn = 0
        total_fp = 0
        total_fn = 0

        for i in range (0, 5):
            
            train_features_X = cross_val_train_features[ : 1635 + (i*109)]
            train_labels_X = cross_val_train_labels[ : 1635 + (i*109)]

            cross_val_test_features_X = cross_val_test_features[i*109 : (i + 1)*109]
            cross_val_test_labels_X = cross_val_test_labels[i*109 : (i + 1)*109]

            rbf_svm_clf_6.fit(train_features_X, train_labels_X)

            train_preds = rbf_svm_clf_6.predict(cross_val_test_features_X)
            
            cm = confusion_matrix(cross_val_test_labels_X, train_preds)
            
            tp = cm[1,1]
            tn = cm[0,0]
            fp = cm[0,1]
            fn = cm[1, 0]
            
            total_tp = total_tp + cm[1, 1]
            total_tn = total_tn + cm[0, 0]
            total_fp = total_fp + cm[0, 1]
            total_fn = total_fn + cm[1, 0]
            
            total_prec = total_prec + (precision_score(cross_val_test_labels_X, train_preds)*(tp+fp))
            
            total_rec = total_rec + (recall_score(cross_val_test_labels_X, train_preds)*(tp+fn))
            
            total_f1 = total_f1 + f1_score(cross_val_test_labels_X, train_preds)
            
            total_acc = total_acc + (accuracy_score(cross_val_test_labels_X, train_preds)*(tp+tn+fp+fn))
          
            Neg_Prec = cm[0,0]/(cm[0,0] + cm[1,0])
            total_neg_prec = total_neg_prec + (Neg_Prec*(tn+fn))
         
            spec = cm[0,0]/(cm[0,0] + cm[0,1])
            total_spec = total_spec + (spec*(tn+fp))
            
            f2 = 2*(Neg_Prec*spec)/(Neg_Prec + spec)
            total_f2 = total_f2 + f2
            
        print("Precision:\n")
        print((total_prec / (total_tp + total_fp))*100)
        
        print("\nRecall:\n")
        print((total_rec/(total_tp + total_fn))*100)
        
        print("\nNegative Precision:\n")
        print((total_neg_prec/(total_tn + total_fn))*100)
        
        print("\nSpecificity:\n")
        print((total_spec/(total_tn + total_fp))*100)
        
        print("\nAccuracy:")
        print((total_acc/(total_tp + total_tn + total_fp + total_fn))*100)
        
        rbf_svm_clf_6.fit(cross_val_train_features[0 : 2180], cross_val_train_labels[0 : 2180])
# Out:
# RBF SVM with C = 1.25 Average Performance Measures:
#
# Precision:
#
# 53.97196261682243
#
# Recall:
#
# 78.57142857142857
#
# Negative Precision:
#
# 46.15384615384615
#
# Specificity:
#
# 21.51394422310757
#
# Accuracy:
# 52.293577981651374
# SVC(C=1.25)

# %%
import pickle


filename = 'RBF_SVM_CLF_6.sav'
pickle.dump(rbf_svm_clf_6, open(filename, 'wb'))

# %%
filename = 'RBF_SVM_CLF_3.sav'
pickle.dump(rbf_svm_clf_3, open(filename, 'wb'))
